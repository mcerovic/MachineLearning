# %%
# Import necessary libraries
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Multinomial linear regression

# %%
data = np.loadtxt('../../data/02_LinearRegression/multinomial.csv', delimiter=',')
x, y = data[:,:2], data[:,2:]
m = x.shape[0]

# %%
x = (x - np.mean(x, axis=0)) / np.std(x, axis=0)
y = (y - np.mean(y)) / np.std(y)

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

ax.scatter(x[:,0], x[:,1], y[:], edgecolors='k', label='Data')
ax.grid(True, color='gray', linestyle='dashed')
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ## Model

# %% [markdown]
# ## Cost function

# %% [markdown]
# ## Optimization

# %% [markdown]
# ## Train

# %%
with tf.Session() as sess:
    
    # TODO: To be able to plot the hypothesis without changing
    # the code, the first value `w` in sess.run([w, b]) should 
    # be a vector of parameters w = [w1, w2] and `b` should 
    # be b = w0
    
    # w, b = sess.run([w, b])

# %%
x1, x2 = np.meshgrid(np.linspace(-2.0, 2.0, 100), np.linspace(-2.0, 2.0, 100))
y1 = x1 * w[0] + x2 * w[1] + b
ax.plot_surface(x1, x2, y1, color='r', alpha=0.5)
fig
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# # Polynomial regression

# %%
# Load data as numpy array
x, y = np.loadtxt('../../data/02_LinearRegression/polynomial.csv', delimiter=',', unpack=True)
m = x.shape[0]

# %%
# Graphical preview
# %matplotlib inline
fig, ax = plt.subplots()
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.scatter(x, y, edgecolors='k', label='Data')
ax.grid(True, color='gray', linestyle='dashed')

# %% [markdown]
# ## Model

# %% [markdown]
# ## Cost

# %% [markdown]
# ## Optimization

# %% [markdown]
# ## Train

# %%
with tf.Session() as sess:

    # TODO: Use > 500 epochs
        
    # TODO: To be able to plot the hypothesis without changing
    # the code, the first value `W` in sess.run(W) should 
    # be a vector of parameters W = [w0, w1, ... wn] 
    
    # w = sess.run(W)

# %%
# Append hypothesis that we found on the plot
x1 = np.linspace(-1.6, 1.6, num=100)
y1 = sum([w[i] * x1 ** i for i in range(6)])
ax.plot(x1, y1, color='r', label='Predicted')
ax.legend()
fig
